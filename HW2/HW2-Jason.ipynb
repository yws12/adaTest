# %%
import re
import requests

from bs4 import BeautifulSoup


# since we are only dealing with the form, we and include the 
# unchanged part of the path in the BASE_URL, otherwise, it 
# should only be the host 'http://isa.epfl.ch/'
BASE_URL = 'http://isa.epfl.ch/imoniteur_ISAP/!GEDPUBLICREPORTS'   

# header dict for our URL extracted postman
# Use Postman to catch headers for one fetch, then we can use
# this header for further use
# 'refer' field is removed though
HEADERS = {
    'Upgrade-Insecure-Requests': '1',
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_0) \
     AppleWebKit/537.36 (KHTML, like Gecko) Chrome/53.0.2785.143 Safari/537.36',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
    'Accept-Encoding': 'gzip, deflate, sdch',
    'Accept-Language': 'en,zh-CN;q=0.8,zh;q=0.6,zh-TW;q=0.4',
    'Cookie': 'LANGUE_LOGIN=en; _gat=1; __utmt_epfl=1; __utmb=33657086.4.10.1476264841; \
     __utma=33657086.1815151521.1470316729.1476270997.1476275339.60; __utmc=33657086; \
     __utmz=33657086.1476270997.59.21.utmcsr=google|utmccn=(organic)|utmcmd=organic| \
     utmctr=(not%20provided); _ga=GA1.2.1815151521.1470316729; _gat_epfl=1; \
     _ga=GA1.2.1815151521.1470316729; __utma=33657086.1815151521.1470316729.1476275339.1476295350.61;\
     __utmc=33657086; __utmz=33657086.1476270997.59.21.utmcsr=google|utmccn=(organic)| \
     utmcmd=organic|utmctr=(not%20provided)',
    'Cache-Control': 'no-cache',
}

# We pre-defined some values because they are invariants among all
# requests: such as we always get HMTL format result, which leads 
# to report_model always to be some preset value
DEFAULT_PARAMS = {
    'ww_i_reportmodel': 133685247,
    'ww_i_reportModelXsl': 133685270,
    'ww_b_list': 1
}

# we map our function paramater names to HTTP request parameter names
# so we don't need to hard-code parameter names
NAME_MAP = {
    'unit': 'ww_x_UNITE_ACAD',
    'academic_year': 'ww_x_PERIODE_ACAD',
    'period': 'ww_x_PERIODE_PEDAGO',
    'semester_type': 'ww_x_HIVERETE'
}

# column index of student table
# to reduce hard-code columns in code
COLUMN_INDEX = {
    'gender': 0,
    'name': 1,
    'specialization': 4,
    'minor': 6,
    'status': 7,
    'sciper': 10
}
    
BACHELOR_PERIODS = [
    'Bachelor semestre 1',
    'Bachelor semestre 2',
    'Bachelor semestre 3',
    'Bachelor semestre 4',
    'Bachelor semestre 5',
    'Bachelor semestre 6'
]

MASTER_PERIODS = [
    'Master semestre 1',
    'Master semestre 2',
    'Master semestre 3',
    'Projet Master automne',
    'Projet Master printemps'
]

# %%
def get_filter_value():
    """
    get all option values, i.e. ww_x_* code for further search
    we do this one-time query and store it in a variable so that
    we don't need to query the code for each condition
    
    return:
        dict: a nested dict containing all options for 4 selects
    """
    
    url = BASE_URL + '.filter'
   
    filter_values = {}

    # remove ww_b_list from params, otherwise all filters will be returned
    new_param = DEFAULT_PARAMS.copy()
    new_param.pop('ww_b_list')
    res = requests.get(url, headers=HEADERS, params=new_param) 
    html = BeautifulSoup(res.text, 'lxml')
    # get all values for all options in 4 select tags
    for dict_name, html_name in NAME_MAP.items():
        # find all options first
        options = html.find('select', {'name': html_name}).find_all('option')
        # key is select tag name, i.e. names of unit/period, value is the value field in the tag
        option_dict = {option.string: option['value'] for option in options if option.string}
        filter_values[dict_name] = option_dict
        
    return filter_values

# %%
def get_GPS_code(filter_values, **filters):
    """
    get GPS code for further fetching student table
    GPS code field will be used in next HTTP query to get student list
    
    Params:
        filter_values (dict): containing all numbers for each select
        filters (dict): containing potential params of filters
    Potential params are following:
        unit (string): academic unit, e.g. Informatique
        academic_year (string): target academic year, e.g. 2016-2017
        period (string): target period, e.g. bachelor semestre 1
        semester_type (string): autumn or spring semester
    """
    url = BASE_URL + '.filter'
    codes = {}
    
    params = DEFAULT_PARAMS.copy()
    if filters:  # at least one filter is specified
        for k, v in filters.items():
            params[NAME_MAP[k]] = filter_values[k][v]
            
        res = requests.get(url, headers=HEADERS, params=params)
        html = BeautifulSoup(res.text, 'lxml')
        gps_elements = html.find_all('a', class_='ww_x_GPS')
        
        for e in gps_elements[1:]:  # remove the first one, Tous
            try:
                # extract GPS number
                codes[e.string] = re.findall('ww_x_GPS=(\d+)', e['onclick'])[0]
            except:
                print('No GPS code found')
    return codes

get_GPS_code(filter_values, unit='Informatique', period='Bachelor semestre 1')

# %%
def get_student_table(gps_codes):
    """
    fetch student table with gps codes
    """
    url = BASE_URL + '.html'
    student_tables = {}
    
    for name, code in gps_codes.items():
        params = DEFAULT_PARAMS.copy()
        # add gps code to request parameter
        params.update({'ww_x_GPS': code})
        res = requests.get(url, headers=HEADERS, params=params)
        html = BeautifulSoup(res.text, 'lxml')
        
        student_table = html.find('table').find_all('tr')[2:]  # remove first two header rows
        stduent_list = []
        
        for student in student_table:
            columns = student.find_all('td')
            student_info = {}  # info about one person is stored as a dict
            for col_name, col_index in COLUMN_INDEX.items():
                student_info[col_name] = columns[col_index].string
                if student_info[col_name]:  # replace unicode space character with space
                    student_info[col_name] = student_info[col_name].replace('\xa0', ' ')
                else:
                    student_info[col_name] = ''  # avoid None
            stduent_list.append(student_info)  # a list of all people under current filters
            
        student_tables[name] = stduent_list
    return student_tables

# %%
def get_all_student_list(stu_type):
    # check input parameter
    if stu_type not in ['bachelor', 'master']:
        print('Not a valid student type')
        return 
    
    filter_values = get_filter_value()
    gps_codes = {}
    periods = BACHELOR_PERIODS if stu_type == 'bachelor' else MASTER_PERIODS
    
    for p in periods:
        # get all gps codes for one period could save some network requests
        # so we don't specify academic_year here
        temp_gps = get_GPS_code(filter_values, unit='Informatique', period=p)
        for k in list(temp_gps.keys()):
            # temp_gps' keys would be like 'Informatique, 2007-2008, Bachelor semestre 2'
            # so split the key into three parts by ', ', then split the second part by '-'
            # finally we could use the first year to find out if it's later than 2007
            # remove undesirable ones
            if k.split(', ')[1].split('-')[0] < '2007':
                temp_gps.pop(k)
        gps_codes.update(temp_gps)
    
    return get_student_table(gps_codes)

# %%
get_all_student_list('master')
# Out:
# {'Informatique, 2007-2008, Master semestre 1': [{'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Aeberhard François-Xavier',
#    'sciper': '153066',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Madame',
#    'minor': None,
#    'name': 'Agarwal Megha',
#    'sciper': '180027',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Anagnostaras David',
#    'sciper': '152232',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Auroux Damien',
#    'sciper': '177395',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Awalebo Joseph',
#    'sciper': '161970',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Balet Ken',
#    'sciper': '166258',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Barazzutti Raphaël Pierre',
#    'sciper': '173600',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Bayramoglu Ersoy',
#    'sciper': '178879',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Madame',
#    'minor': None,
#    'name': 'Benabdallah Zeineb',
#    'sciper': '154573',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Bettex Marc',
#    'sciper': '160492',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Billaud Joël',
#    'sciper': '172687',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Brightwell Mark',
#    'sciper': '179802',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Madame',
#    'minor': None,
#    'name': 'Bucher Cécile',
#    'sciper': '162618',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Campora Simone',
#    'sciper': '180072',
#    'specialization': 'Internet computing',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Cardinaux Damien',
#    'sciper': '146330',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Madame',
#    'minor': None,
#    'name': 'Casati Nathalie',
#    'sciper': '160148',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Cassata Alexandre',
#    'sciper': '160225',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Cassina Ilya',
#    'sciper': '153746',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Copponnex Hadrien',
#    'sciper': '160718',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Droz-dit-Busset Arnault',
#    'sciper': '138088',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Dumont Loïc',
#    'sciper': '154643',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Dupasquier Benoît',
#    'sciper': '166772',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Fardel Ludovic',
#    'sciper': '167168',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Fleury Marc-Olivier',
#    'sciper': '166805',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Fomene Tierry Alain',
#    'sciper': '154080',
#    'specialization': None,
#    'status': 'Congé'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Galdos Andoni',
#    'sciper': '169702',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Garessus Samuel',
#    'sciper': '180161',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Garg Nikhil',
#    'sciper': '172264',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Gascon Grégory',
#    'sciper': '160578',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Gfeller Sebastian',
#    'sciper': '161357',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Heath Quentin',
#    'sciper': '177399',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Heiniger Nicolas',
#    'sciper': '166921',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Hofer Thomas',
#    'sciper': '165819',
#    'specialization': 'Foundations of Software',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Hottelier Thibaud',
#    'sciper': '166229',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Ibarguren Ibai',
#    'sciper': '173902',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Imperatori Alexandre',
#    'sciper': '166491',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Joaquim David',
#    'sciper': '166124',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Junod Antoine',
#    'sciper': '146929',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Koganei Olivier',
#    'sciper': '180313',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Kohler Johann',
#    'sciper': '160254',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Koller Yannick',
#    'sciper': '169734',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Madame',
#    'minor': None,
#    'name': 'Krishnan Sukanya',
#    'sciper': '179800',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Kwanga Rodrigue',
#    'sciper': '172611',
#    'specialization': 'Biocomputing',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Lavanchy Cédric',
#    'sciper': '166935',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Losa Giuliano',
#    'sciper': '179339',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Madame',
#    'minor': None,
#    'name': 'Lotfi Jocelyne',
#    'sciper': '166029',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Madame',
#    'minor': None,
#    'name': 'Marian Ludmila',
#    'sciper': '179930',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Marmori Federico',
#    'sciper': '161794',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Madame',
#    'minor': None,
#    'name': 'Meinen Jennifer',
#    'sciper': '161024',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Moulin François',
#    'sciper': '167133',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Muriel Hugo Marcelo',
#    'sciper': '179878',
#    'specialization': 'Internet computing',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Ngallemo Hever Patrick',
#    'sciper': '160893',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Ninkovic Marko',
#    'sciper': '180269',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Pakzad Pooya',
#    'sciper': '180160',
#    'specialization': 'Internet computing',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Pilchen Jerome',
#    'sciper': '177636',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Plancherel Pascal',
#    'sciper': '166262',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Pollet Christophe',
#    'sciper': '179716',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Rabie Stéphane',
#    'sciper': '177393',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Ragnerstam Erik',
#    'sciper': '177476',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Madame',
#    'minor': None,
#    'name': 'Rochat Aurélia',
#    'sciper': '166079',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Roux Alexandre',
#    'sciper': '166263',
#    'specialization': 'Foundations of Software',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Sauthier Ludovic',
#    'sciper': '161138',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Schintgen Joël',
#    'sciper': '160991',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Signori Jean',
#    'sciper': '155018',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Spiess Christophe',
#    'sciper': '167387',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Stachowiak Robert',
#    'sciper': '174036',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Suter François',
#    'sciper': '154706',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Madame',
#    'minor': None,
#    'name': 'Tomar Anmol',
#    'sciper': '178057',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Wei Zhe',
#    'sciper': '155097',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Zalakain Ilazki',
#    'sciper': '169839',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Zufferey Damien',
#    'sciper': '166264',
#    'specialization': None,
#    'status': 'Présent'}],
#  'Informatique, 2007-2008, Master semestre 2': [{'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Aeberhard François-Xavier',
#    'sciper': '153066',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Madame',
#    'minor': None,
#    'name': 'Agarwal Megha',
#    'sciper': '180027',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': 'Mineur en Management, technologie et entrepreneuriat',
#    'name': 'Anagnostaras David',
#    'sciper': '152232',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Auroux Damien',
#    'sciper': '177395',
#    'specialization': 'Internet computing',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Awalebo Joseph',
#    'sciper': '161970',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Balet Ken',
#    'sciper': '166258',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Barazzutti Raphaël Pierre',
#    'sciper': '173600',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Bayramoglu Ersoy',
#    'sciper': '178879',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Bécholey Alexandre',
#    'sciper': '160213',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Madame',
#    'minor': None,
#    'name': 'Benabdallah Zeineb',
#    'sciper': '154573',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Bettex Marc',
#    'sciper': '160492',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Billaud Joël',
#    'sciper': '172687',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Bozzo Vincent',
#    'sciper': '153742',
#    'specialization': 'Signals, Images and Interfaces',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Brightwell Mark',
#    'sciper': '179802',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Madame',
#    'minor': None,
#    'name': 'Bucher Cécile',
#    'sciper': '162618',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Campora Simone',
#    'sciper': '180072',
#    'specialization': 'Internet computing',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Cantale Nicolas',
#    'sciper': '153324',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Cardinaux Damien',
#    'sciper': '146330',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Madame',
#    'minor': None,
#    'name': 'Casati Nathalie',
#    'sciper': '160148',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Cassata Alexandre',
#    'sciper': '160225',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Cassina Ilya',
#    'sciper': '153746',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Copponnex Hadrien',
#    'sciper': '160718',
#    'specialization': 'Foundations of Software',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Di Maïo Vincent',
#    'sciper': '166001',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Madame',
#    'minor': None,
#    'name': 'Diatchka Kremena Sotirova',
#    'sciper': '172500',
#    'specialization': 'Biocomputing',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Dumont Loïc',
#    'sciper': '154643',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Dupasquier Benoît',
#    'sciper': '166772',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Fardel Ludovic',
#    'sciper': '167168',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Fleury Marc-Olivier',
#    'sciper': '166805',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Fomene Tierry Alain',
#    'sciper': '154080',
#    'specialization': None,
#    'status': 'Congé'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Galdos Andoni',
#    'sciper': '169702',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Garg Nikhil',
#    'sciper': '172264',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Gascon Grégory',
#    'sciper': '160578',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Gfeller Sebastian',
#    'sciper': '161357',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Gulati Asheesh',
#    'sciper': '128911',
#    'specialization': 'Internet computing',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Heath Quentin',
#    'sciper': '177399',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Heiniger Nicolas',
#    'sciper': '166921',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Hofer Thomas',
#    'sciper': '165819',
#    'specialization': 'Foundations of Software',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Hottelier Thibaud',
#    'sciper': '166229',
#    'specialization': 'Foundations of Software',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Ibarguren Ibai',
#    'sciper': '173902',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Imperatori Alexandre',
#    'sciper': '166491',
#    'specialization': None,
#    'status': 'Congé'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Jaggi Andreas',
#    'sciper': '159771',
#    'specialization': 'Internet computing',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Joaquim David',
#    'sciper': '166124',
#    'specialization': 'Foundations of Software',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Junod Antoine',
#    'sciper': '146929',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Junod Cyril',
#    'sciper': '154484',
#    'specialization': 'Internet computing',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Khan Suleiman',
#    'sciper': '154503',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Koganei Olivier',
#    'sciper': '180313',
#    'specialization': 'Internet computing',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Kohler Johann',
#    'sciper': '160254',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Koller Yannick',
#    'sciper': '169734',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Madame',
#    'minor': None,
#    'name': 'Krishnan Sukanya',
#    'sciper': '179800',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Küng Olivier',
#    'sciper': '161058',
#    'specialization': 'Signals, Images and Interfaces',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Kwanga Rodrigue',
#    'sciper': '172611',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Lavanchy Cédric',
#    'sciper': '166935',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Losa Giuliano',
#    'sciper': '179339',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Madame',
#    'minor': None,
#    'name': 'Lotfi Jocelyne',
#    'sciper': '166029',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Madame',
#    'minor': None,
#    'name': 'Makeeva Polina',
#    'sciper': '161336',
#    'specialization': 'Foundations of Software',
#    'status': 'Présent'},
#   {'gender': 'Madame',
#    'minor': None,
#    'name': 'Marian Ludmila',
#    'sciper': '179930',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Marmori Federico',
#    'sciper': '161794',
#    'specialization': 'Foundations of Software',
#    'status': 'Présent'},
#   {'gender': 'Madame',
#    'minor': None,
#    'name': 'Meinen Jennifer',
#    'sciper': '161024',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Moulin François',
#    'sciper': '167133',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Muñoz Iván',
#    'sciper': '161344',
#    'specialization': 'Computer Engineering - SP',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Muriel Hugo Marcelo',
#    'sciper': '179878',
#    'specialization': 'Internet computing',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Ngallemo Hever Patrick',
#    'sciper': '160893',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Ni Zhong Zhong',
#    'sciper': '129326',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Ninkovic Marko',
#    'sciper': '180269',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Pakzad Pooya',
#    'sciper': '180160',
#    'specialization': 'Internet computing',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Pilchen Jerome',
#    'sciper': '177636',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Plancherel Pascal',
#    'sciper': '166262',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Pollet Christophe',
#    'sciper': '179716',
#    'specialization': 'Internet computing',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Rabie Stéphane',
#    'sciper': '177393',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Ragnerstam Erik',
#    'sciper': '177476',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Madame',
#    'minor': None,
#    'name': 'Rochat Aurélia',
#    'sciper': '166079',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Roux Alexandre',
#    'sciper': '166263',
#    'specialization': 'Foundations of Software',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Sauthier Ludovic',
#    'sciper': '161138',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Schintgen Joël',
#    'sciper': '160991',
#    'specialization': 'Internet computing',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Signori Jean',
#    'sciper': '155018',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Spiess Christophe',
#    'sciper': '167387',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Stachowiak Robert',
#    'sciper': '174036',
#    'specialization': 'Signals, Images and Interfaces',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Suter François',
#    'sciper': '154706',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Taggiasco Matthieu',
#    'sciper': '167447',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Madame',
#    'minor': None,
#    'name': 'Tomar Anmol',
#    'sciper': '178057',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Wafellman Jonathan',
#    'sciper': '155093',
#    'specialization': 'Internet computing',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Wei Zhe',
#    'sciper': '155097',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Yersin Antoine',
#    'sciper': '155124',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Zalakain Ilazki',
#    'sciper': '169839',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Zheng Da',
#    'sciper': '172221',
#    'specialization': 'Internet computing',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Zhou Maoan',
#    'sciper': '129093',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Zufferey Damien',
#    'sciper': '166264',
#    'specialization': 'Foundations of Software',
#    'status': 'Présent'}],
#  'Informatique, 2007-2008, Master semestre 3': [{'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Benda Lukas',
#    'sciper': '154419',
#    'specialization': 'Signals, Images and Interfaces',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Bozzo Vincent',
#    'sciper': '153742',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Brandinu Guillaume',
#    'sciper': '153664',
#    'specialization': 'Signals, Images and Interfaces',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Brutsche Florian',
#    'sciper': '159852',
#    'specialization': 'Internet computing',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Cantale Nicolas',
#    'sciper': '153324',
#    'specialization': None,
#    'status': 'Congé'},
#   {'gender': 'Madame',
#    'minor': None,
#    'name': 'Cetin Feride',
#    'sciper': '173573',
#    'specialization': 'Internet computing',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': 'Mineur en Management, technologie et entrepreneuriat',
#    'name': 'Chipounov Vitaly',
#    'sciper': '160391',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Clivaz Jean-Philippe',
#    'sciper': '145546',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Conus Christian',
#    'sciper': '147358',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Conus Pascal',
#    'sciper': '154465',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Coppel Yohann',
#    'sciper': '160239',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'De Lamarter Erik',
#    'sciper': '146752',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Madame',
#    'minor': None,
#    'name': 'Diatchka Kremena Sotirova',
#    'sciper': '172500',
#    'specialization': 'Biocomputing',
#    'status': 'Stage'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Dotta Mirco',
#    'sciper': '153819',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Dubout Charles',
#    'sciper': '160831',
#    'specialization': 'Biocomputing',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': 'Mineur en Management, technologie et entrepreneuriat',
#    'name': 'Dubut Frédéric',
#    'sciper': '172257',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Evans Nathaniel',
#    'sciper': '172503',
#    'specialization': 'Biocomputing',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Eyer Leander',
#    'sciper': '160915',
#    'specialization': 'Foundations of Software',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Favre Cédric',
#    'sciper': '153641',
#    'specialization': 'Internet computing',
#    'status': 'Présent'},
#   {'gender': 'Madame',
#    'minor': None,
#    'name': 'Garg Neha Priyadarshini',
#    'sciper': '172240',
#    'specialization': None,
#    'status': 'Stage'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Giuclea Ràzvan',
#    'sciper': '154186',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Gobet Olivier',
#    'sciper': '153882',
#    'specialization': 'Foundations of Software',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Gulati Asheesh',
#    'sciper': '128911',
#    'specialization': 'Internet computing',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Habersaat Alexandre',
#    'sciper': '161090',
#    'specialization': 'Biocomputing',
#    'status': 'Présent'},
#   {'gender': 'Madame',
#    'minor': None,
#    'name': 'Hanser Cyrielle Morgane',
#    'sciper': '153506',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Madame',
#    'minor': None,
#    'name': 'Henriot Laetitia',
#    'sciper': '146441',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Herrmann Alexandre',
#    'sciper': '153891',
#    'specialization': 'Internet computing',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Hügli Michael',
#    'sciper': '145957',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': 'Mineur en Management, technologie et entrepreneuriat',
#    'name': 'Imhoff Lionel',
#    'sciper': '153642',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Indra Saurabh',
#    'sciper': '173257',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Israël Joël',
#    'sciper': '160247',
#    'specialization': 'Signals, Images and Interfaces',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Jaggi Andreas',
#    'sciper': '159771',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Junod Cyril',
#    'sciper': '154484',
#    'specialization': 'Internet computing',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Khan Suleiman',
#    'sciper': '154503',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Kornaros Nikolaos',
#    'sciper': '154106',
#    'specialization': 'Internet computing',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Küng Olivier',
#    'sciper': '161058',
#    'specialization': 'Signals, Images and Interfaces',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Lépine Simon',
#    'sciper': '160150',
#    'specialization': 'Biocomputing',
#    'status': 'Présent'},
#   {'gender': 'Madame',
#    'minor': None,
#    'name': 'Makeeva Polina',
#    'sciper': '161336',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': "Matthey-de-l'Endroit Loïc",
#    'sciper': '153640',
#    'specialization': 'Biocomputing',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Mazouer Philippe',
#    'sciper': '159814',
#    'specialization': 'Signals, Images and Interfaces',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Muñoz Iván',
#    'sciper': '161344',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Nansi Fabrice Cédric',
#    'sciper': '148900',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Ni Zhong Zhong',
#    'sciper': '129326',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Madame',
#    'minor': None,
#    'name': 'Oguz Gizil',
#    'sciper': '172859',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Payot Jonathan',
#    'sciper': '154420',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Pazeller Vincent',
#    'sciper': '160208',
#    'specialization': 'Internet computing',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Peppicelli Daniel',
#    'sciper': '154685',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Ramareddy Sammy',
#    'sciper': '154933',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Madame',
#    'minor': None,
#    'name': 'Reissner Coralie',
#    'sciper': '159210',
#    'specialization': 'Signals, Images and Interfaces',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Resin Pascal',
#    'sciper': '154936',
#    'specialization': 'Biocomputing',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Rey Charles François',
#    'sciper': '147362',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Robert Pierre-Alain',
#    'sciper': '147445',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': 'Mineur en Management, technologie et entrepreneuriat',
#    'name': 'Rosat Damien',
#    'sciper': '153645',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Ruffieux Simon',
#    'sciper': '154969',
#    'specialization': 'Biocomputing',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Ruffin Julien',
#    'sciper': '153805',
#    'specialization': 'Internet computing',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Schönmann Patrick',
#    'sciper': '147366',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Singla Adish Kumar',
#    'sciper': '167854',
#    'specialization': None,
#    'status': 'Stage'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Suter Philippe Paul Henri',
#    'sciper': '161402',
#    'specialization': 'Foundations of Software',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Tagliani Raphaël',
#    'sciper': '152238',
#    'specialization': 'Internet computing',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Venkateshwaran Ganesh',
#    'sciper': '159770',
#    'specialization': 'Internet computing',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Wafellman Jonathan',
#    'sciper': '155093',
#    'specialization': 'Internet computing',
#    'status': 'Présent'},
#   {'gender': 'Madame',
#    'minor': None,
#    'name': 'Wang Zufferey Yuanjian',
#    'sciper': '171511',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Yersin Antoine',
#    'sciper': '155124',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Zheng Da',
#    'sciper': '172221',
#    'specialization': None,
#    'status': 'Stage'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Zhou Maoan',
#    'sciper': '129093',
#    'specialization': None,
#    'status': 'Stage'}],
#  'Informatique, 2007-2008, Projet Master automne': [{'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Stewart Conail',
#    'sciper': '173527',
#    'specialization': None,
#    'status': 'Présent'}],
#  'Informatique, 2007-2008, Projet Master printemps': [{'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Brutsche Florian',
#    'sciper': '159852',
#    'specialization': 'Internet computing',
#    'status': 'Congé'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Dotta Mirco',
#    'sciper': '153819',
#    'specialization': None,
#    'status': 'Stage'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Hügli Michael',
#    'sciper': '145957',
#    'specialization': None,
#    'status': 'Stage'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Indra Saurabh',
#    'sciper': '173257',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Lépine Simon',
#    'sciper': '160150',
#    'specialization': 'Biocomputing',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Stewart Conail',
#    'sciper': '173527',
#    'specialization': None,
#    'status': 'Présent'}],
#  'Informatique, 2008-2009, Master semestre 1': [{'gender': 'Madame',
#    'minor': None,
#    'name': 'Aydin Ebru',
#    'sciper': '183512',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Bakshev Stanimir',
#    'sciper': '185607',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Bécholey Alexandre',
#    'sciper': '160213',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Blanvillain Christian',
#    'sciper': '184737',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Boksanyi Michael',
#    'sciper': '161634',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Bolkensteyn Dinesh',
#    'sciper': '170451',
#    'specialization': None,
#    'status': 'Stage'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Bonnet Rémi',
#    'sciper': '183895',
#    'specialization': 'Foundations of Software',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Bornet Cyril Antoine Michel',
#    'sciper': '170219',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Bouaziz Sofien',
#    'sciper': '179749',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Cassina Ilya',
#    'sciper': '153746',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Conus Johann',
#    'sciper': '153762',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Crisan Daniel',
#    'sciper': '183920',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Cunha Pedro Andre',
#    'sciper': '185523',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Delort Vincent',
#    'sciper': '166548',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Di Maïo Vincent',
#    'sciper': '166001',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Donzé Benjamin',
#    'sciper': '166746',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Dos Santos Patrick',
#    'sciper': '166748',
#    'specialization': None,
#    'status': 'Congé'},
#   {'gender': 'Monsieur',
#    'minor': 'Mineur en Management, technologie et entrepreneuriat',
#    'name': 'Droz Olivier',
#    'sciper': '166751',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Eberle Julien',
#    'sciper': '170414',
#    'specialization': 'Internet computing',
#    'status': 'Congé'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Evans William Christopher',
#    'sciper': '183256',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Franco Londono Leandro',
#    'sciper': '184112',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Genet Henry',
#    'sciper': '166889',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Gratsias Georgios',
#    'sciper': '183629',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Madame',
#    'minor': None,
#    'name': 'Grivet Ekaterina',
#    'sciper': '161091',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Gvianishvili Giorgi',
#    'sciper': '183534',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Madame',
#    'minor': None,
#    'name': 'Ilie Diana',
#    'sciper': '185005',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Imperatori Alexandre',
#    'sciper': '166491',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Madame',
#    'minor': None,
#    'name': 'Jesse Julia',
#    'sciper': '159998',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Jonnalagedda Manohar',
#    'sciper': '170823',
#    'specialization': 'Foundations of Software',
#    'status': 'Présent'},
#   {'gender': 'Madame',
#    'minor': None,
#    'name': 'Kostic Teodora',
#    'sciper': '183605',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Laprade Philippe',
#    'sciper': '170241',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Lauber Jonas',
#    'sciper': '170242',
#    'specialization': None,
#    'status': 'Congé'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Lorch Daniel',
#    'sciper': '165562',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Ly Hoang Hai',
#    'sciper': '183482',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Mader Arnaud',
#    'sciper': '166260',
#    'specialization': None,
#    'status': 'Congé'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Marfurt Nicolas',
#    'sciper': '167313',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Marinescu Paul Dan',
#    'sciper': '183398',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Marx Clément',
#    'sciper': '146742',
#    'specialization': 'Signals, Images and Interfaces',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Mayer Mikael',
#    'sciper': '183900',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Neu Raoul',
#    'sciper': '171028',
#    'specialization': 'Internet computing',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Nguyen Quoc Viet Hung',
#    'sciper': '183476',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Nguyen-Xuan Jérémy',
#    'sciper': '167386',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Popovic Miroslav',
#    'sciper': '183055',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Raja Yanick',
#    'sciper': '159516',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Sahy François',
#    'sciper': '161127',
#    'specialization': None,
#    'status': 'Congé'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Shastry Bhargava',
#    'sciper': '185480',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Sotiropoulos Ioannis',
#    'sciper': '185458',
#    'specialization': 'Computer Engineering - SP',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Sripada Raja Babu',
#    'sciper': '185587',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Stachowiak Robert',
#    'sciper': '174036',
#    'specialization': None,
#    'status': 'Stage'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Stephan Mathieu',
#    'sciper': '179756',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Stroe Bogdan',
#    'sciper': '186060',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Stroe Dante',
#    'sciper': '185522',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Studer Emeric',
#    'sciper': '184647',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Taggiasco Matthieu',
#    'sciper': '167447',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Tangui Achraf',
#    'sciper': '167045',
#    'specialization': None,
#    'status': 'Stage'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Vogt Pascal',
#    'sciper': '170265',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Waldmeyer Marc',
#    'sciper': '167439',
#    'specialization': None,
#    'status': 'Congé'},
#   {'gender': 'Madame',
#    'minor': None,
#    'name': 'Yurovsky Alisa',
#    'sciper': '183185',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Zotos Panteleimon',
#    'sciper': '183628',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Züger Walter',
#    'sciper': '171042',
#    'specialization': None,
#    'status': 'Congé'}],
#  'Informatique, 2008-2009, Master semestre 2': [{'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Aeberhard François-Xavier',
#    'sciper': '153066',
#    'specialization': None,
#    'status': 'Stage'},
#   {'gender': 'Madame',
#    'minor': None,
#    'name': 'Aydin Ebru',
#    'sciper': '183512',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Bakshev Stanimir',
#    'sciper': '185607',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Bécholey Alexandre',
#    'sciper': '160213',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Madame',
#    'minor': None,
#    'name': 'Benabdallah Zeineb',
#    'sciper': '154573',
#    'specialization': 'Biocomputing',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Blanvillain Christian',
#    'sciper': '184737',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Boksanyi Michael',
#    'sciper': '161634',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Bolkensteyn Dinesh',
#    'sciper': '170451',
#    'specialization': None,
#    'status': 'Stage'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Bonnet Rémi',
#    'sciper': '183895',
#    'specialization': 'Foundations of Software',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Bornet Cyril Antoine Michel',
#    'sciper': '170219',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Conus Johann',
#    'sciper': '153762',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Crisan Daniel',
#    'sciper': '183920',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Cunha Pedro Andre',
#    'sciper': '185523',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Delort Vincent',
#    'sciper': '166548',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Di Maïo Vincent',
#    'sciper': '166001',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Donzé Benjamin',
#    'sciper': '166746',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Dos Santos Patrick',
#    'sciper': '166748',
#    'specialization': None,
#    'status': 'Congé'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Droz Olivier',
#    'sciper': '166751',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Eberle Julien',
#    'sciper': '170414',
#    'specialization': 'Internet computing',
#    'status': 'Congé'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Fardel Ludovic',
#    'sciper': '167168',
#    'specialization': None,
#    'status': 'Stage'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Fomene Tierry Alain',
#    'sciper': '154080',
#    'specialization': 'Internet computing',
#    'status': 'Stage'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Franco Londono Leandro',
#    'sciper': '184112',
#    'specialization': None,
# ...
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': 'Information security minor',
#    'name': 'Mouchet Christian Vincent',
#    'sciper': '217453',
#    'specialization': None,
#    'status': 'Stage'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Muth Joachim',
#    'sciper': '214757',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Madame',
#    'minor': None,
#    'name': 'Nikitina Tatiana',
#    'sciper': '245685',
#    'specialization': 'Internet computing',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Nimier-David Merlin Eléazar',
#    'sciper': '247309',
#    'specialization': None,
#    'status': 'Stage'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Nurlu Gökçen',
#    'sciper': '254650',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Ottet Loïc',
#    'sciper': '225743',
#    'specialization': 'Foundations of Software',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Overney Tristan David',
#    'sciper': '217280',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Parmantier Hector Andreas Alexandre',
#    'sciper': '225757',
#    'specialization': 'Data Analytics',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Pestalozzi Rossi Lukas Andri',
#    'sciper': '227660',
#    'specialization': 'Internet computing',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Pirelli Solal Vincenzo',
#    'sciper': '223572',
#    'specialization': 'Software Systems',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Plancherel Nicolas Bernard Lucien',
#    'sciper': '217393',
#    'specialization': None,
#    'status': 'Stage'},
#   {'gender': 'Madame',
#    'minor': None,
#    'name': 'Popovic Radmila',
#    'sciper': '251558',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Racine Jason Rémy',
#    'sciper': '244270',
#    'specialization': None,
#    'status': 'Stage'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Raemy Baptiste',
#    'sciper': '228358',
#    'specialization': 'Internet computing',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Raho Moritz Fabian',
#    'sciper': '225274',
#    'specialization': 'Software Systems',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Regamey Samuel',
#    'sciper': '184366',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Reich Nicolas Alexandre',
#    'sciper': '223287',
#    'specialization': 'Internet computing',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Renucci Allan Vincent Roger',
#    'sciper': '205095',
#    'specialization': None,
#    'status': 'Stage'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Rouault Sébastien Louis Alexandre',
#    'sciper': '260806',
#    'specialization': 'Software Systems',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Roulin Andy',
#    'sciper': '216690',
#    'specialization': 'Computer Engineering - SP',
#    'status': 'Présent'},
#   {'gender': 'Madame',
#    'minor': 'Mineur en Management, technologie et entrepreneuriat',
#    'name': 'Salathé Joanna Béatrice',
#    'sciper': '217489',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Sarigiannis Dimitrios',
#    'sciper': '256553',
#    'specialization': 'Data Analytics',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Schaeffer Yannick',
#    'sciper': '186020',
#    'specialization': 'Software Systems',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Séchaud Gaétan',
#    'sciper': '217500',
#    'specialization': None,
#    'status': 'Stage'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Séguy Louis Marie James',
#    'sciper': '204222',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Semple Alexis Nabil',
#    'sciper': '224304',
#    'specialization': 'Internet computing',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Sottas Baptiste',
#    'sciper': '217056',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': 'Mineur en Management, technologie et entrepreneuriat',
#    'name': 'Sympetheros Alexandros',
#    'sciper': '256612',
#    'specialization': None,
#    'status': 'Stage'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Tafani-Dereeper Christophe Clément',
#    'sciper': '223529',
#    'specialization': None,
#    'status': 'Stage'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Theytaz Joël Régis',
#    'sciper': '227590',
#    'specialization': 'Information Security - SP',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Torche Jérôme William',
#    'sciper': '224639',
#    'specialization': 'Internet computing',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Vassor Martin Thomas',
#    'sciper': '223825',
#    'specialization': 'Computer Engineering - SP',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Vessaz Yannick',
#    'sciper': '225096',
#    'specialization': 'Internet computing',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Veuthey Alexandre Bernard Robert',
#    'sciper': '224295',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': 'Mineur en Neurosciences computationnelles',
#    'name': 'Vostriakov Alexander',
#    'sciper': '196683',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Wang Junxiong',
#    'sciper': '254478',
#    'specialization': None,
#    'status': 'Stage'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Yüzügüler Ahmet Caner',
#    'sciper': '240268',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Zakhour George',
#    'sciper': '261146',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Madame',
#    'minor': None,
#    'name': 'Zhou Lisa',
#    'sciper': '256870',
#    'specialization': None,
#    'status': 'Stage'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Zimmermann Florian',
#    'sciper': '170946',
#    'specialization': 'Signals, Images and Interfaces',
#    'status': 'Présent'}],
#  'Informatique, 2016-2017, Projet Master automne': [{'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Amiguet Jérôme',
#    'sciper': '166075',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Antognini Diego Matteo',
#    'sciper': '243163',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Antognini Marco',
#    'sciper': '194182',
#    'specialization': 'Foundations of Software',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': 'Mineur en Management, technologie et entrepreneuriat',
#    'name': 'Bouquet Stéphane',
#    'sciper': '213664',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Bovet Sidney',
#    'sciper': '214637',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Brechbühler Gil',
#    'sciper': '243164',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Canale Raffaele',
#    'sciper': '203947',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': 'Mineur en Management, technologie et entrepreneuriat',
#    'name': 'Cao Huu-Ân',
#    'sciper': '203945',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': 'Mineur en Management, technologie et entrepreneuriat',
#    'name': 'Cardoso Rodrigues Bonifácio Vítor Gonçalo',
#    'sciper': '244136',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'De Vecchi Guillaume Paul Louis',
#    'sciper': '229467',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Débieux Vincent',
#    'sciper': '224704',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Drobnjak Nemanja',
#    'sciper': '245486',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Dubedat Philippe Pierre-Elie',
#    'sciper': '259766',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Duhem Martin Nicolas',
#    'sciper': '214632',
#    'specialization': 'Foundations of Software',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'El Houti Youssef',
#    'sciper': '194328',
#    'specialization': 'Information Security - SP',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'El Khoury Raphael',
#    'sciper': '212765',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Engilberge Martin Pierre',
#    'sciper': '212790',
#    'specialization': 'Internet computing',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Farcasanu Alexandru-Ciprian',
#    'sciper': '254604',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Favrod Philémon Orphée',
#    'sciper': '218353',
#    'specialization': 'Computer Engineering - SP',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Ferrier Etienne Pierre Maurice',
#    'sciper': '255137',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Fokeas Sotirios',
#    'sciper': '260636',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Galissard de Marignac Vincent',
#    'sciper': '186260',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Gaspoz John',
#    'sciper': '212859',
#    'specialization': 'Information Security - SP',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Gilgien David Yann',
#    'sciper': '217632',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Grütter Karl Samuel',
#    'sciper': '201600',
#    'specialization': 'Foundations of Software',
#    'status': 'Congé'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Guliyev Khayyam Mubariz Oglu',
#    'sciper': '247455',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Ionescu Vlad Nicolae',
#    'sciper': '255163',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Junker Florian Christophe',
#    'sciper': '204253',
#    'specialization': 'Internet computing',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Leiva Loris Angel',
#    'sciper': '227356',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Loiseleur Thibaut',
#    'sciper': '260811',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Maitre Grégory Ludovic',
#    'sciper': '214200',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': 'Information security minor',
#    'name': 'Majeri Kasmaei Chervine',
#    'sciper': '227848',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Madame',
#    'minor': None,
#    'name': 'Manasovska Ana',
#    'sciper': '235878',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Mizraji Thomas',
#    'sciper': '228496',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Oliveira Andrade Patrick Daniel',
#    'sciper': '213584',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Madame',
#    'minor': None,
#    'name': 'Pignat Eliéva Arlette',
#    'sciper': '217301',
#    'specialization': 'Computer Engineering - SP',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Piskas Georgios',
#    'sciper': '244587',
#    'specialization': 'Software Systems',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Qureshi Zaid',
#    'sciper': '256722',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Rabasco Jérémy',
#    'sciper': '214273',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Robert Arnaud',
#    'sciper': '214101',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Rousseau Adrien Jean-Louis',
#    'sciper': '259910',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Rudelle Matthieu François Edgard',
#    'sciper': '216702',
#    'specialization': 'Internet computing',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Sbai Hugo',
#    'sciper': '225323',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Madame',
#    'minor': None,
#    'name': 'Sbai Marion Fadoi',
#    'sciper': '225388',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Schegg Elias',
#    'sciper': '195675',
#    'specialization': 'Internet computing',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Schmutz Michaël Steven',
#    'sciper': '202373',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Sikiaridis Alexandre Jean Denis',
#    'sciper': '217469',
#    'specialization': 'Foundations of Software',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Szabo Kristof Tamas',
#    'sciper': '193832',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Tallec Corentin Jean Daniel',
#    'sciper': '256846',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Taneli Deniz',
#    'sciper': '240155',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Tang Tinh Di David',
#    'sciper': '225316',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Valette Laurent Michel',
#    'sciper': '205864',
#    'specialization': 'Software Systems',
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Vessaz Florian',
#    'sciper': '202508',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Madame',
#    'minor': None,
#    'name': 'Wang Zisi',
#    'sciper': '245527',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Monsieur',
#    'minor': None,
#    'name': 'Wickramasinghe Pamuditha Udaranga',
#    'sciper': '229235',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Madame',
#    'minor': None,
#    'name': 'Zaridze Ketevani',
#    'sciper': '244283',
#    'specialization': None,
#    'status': 'Présent'},
#   {'gender': 'Madame',
#    'minor': None,
#    'name': 'Zhang Jin',
#    'sciper': '245293',
#    'specialization': None,
#    'status': 'Congé'}],
#  'Informatique, 2016-2017, Projet Master printemps': [],
#  'Informatique, 2017-2018, Master semestre 3': [],
#  'Informatique, 2017-2018, Projet Master automne': [],
#  'Informatique, 2017-2018, Projet Master printemps': []}
